# %% [markdown]
# ## Changelog
# - parent: root
# - change: tiny baseline
# - hypothesis: smoke test

# %%
import pandas as pd
from pathlib import Path
Path('submission.csv').write_text('PassengerId,Survived\n1,0\n2,1\n')
